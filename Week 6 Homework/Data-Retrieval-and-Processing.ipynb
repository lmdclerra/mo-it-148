# %%
# Week 6 Homework: Data Retrieval and Processing

# This script is intended to be run in a Jupyter Notebook environment.
# To run this script, ensure you have Jupyter Notebook installed and running.

# You can install Jupyter Notebook using pip:
# %pip install notebook

# You can start Jupyter Notebook by running the following command in your terminal:
# $ jupyter notebook 

# This script connects to a local Ganache blockchain using Web3.py.
# Make sure you have Ganache running and Web3.py installed.
# %pip install web3

from web3 import Web3
import json, time


# Load CSV file from your Homework 1
import pandas as pd


# Load IoT sensor data from CSV file (Generated in Homework 1)
iot_df = pd.read_csv('Week 6 Homework/iot_data.csv')

# Display the first few rows of the DataFrame
print(iot_df.head())

# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

# Check if connected to Ganache
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
    exit()

# Replace with actual contract address form Remix 
contract_address = "0xd031B8de5e372d5c40040c93e387c4240350B7bF"

# Paste the ABI from Remix 
# abi = [...] # Replace with the actual ABI of your contract

# If you have the ABI in a file, you can load it like this:
with open('Week 6 Homework/copy-of-abi.json', 'r') as abi_file:
    abi = json.load(abi_file)

# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)

# Set the default sender address (the first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")


# Send the IoT data to the blockchain. Each row from the CSV file will be stored as a transaction on the blockchain.
def send_iot_data(package_id, gps_coords, temperature, status):
    
    txn = contract.functions.storeData(
        package_id,
        gps_coords,
        temperature,
        status
    ).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
    
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Data Stored {package_id} GPS: {gps_coords:>23} Temp: {temperature}  Status: {status:<10} at block {
        receipt.blockNumber:>3} Txn hash {receipt.transactionHash.hex()}")


# Iterate through the DataFrame and send each row to the blockchain
for index, row in iot_df.iterrows():

    package_id  = str(row['package_id'  ])
    gps_coords  = str(row['gps_coords'  ])
    temperature = str(row['temperature' ])
    status      = str(row['status'      ])    

    send_iot_data(package_id, gps_coords, temperature, status)    
    time.sleep(1)  # sleep to avoid hitting the gas limit too quickly

# now that the data is on the blockchain, we can retrieve it to verify storage
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")

# retrieve and print a specific record (e.g., the first one)
record = contract.functions.getRecord(0).call()
print(f"First Stored Record : {record}")
# Out:
#                timestamp package_id               gps_coords temperature  \
# 0  2025-06-02T21:36:32I0     PKG001   (7.839114, 125.820784)        29 C
# 1  2025-06-02T21:36:32I1     PKG002  (16.754497, 116.599905)        24 C
# 2  2025-06-02T21:36:32I2     PKG003  (16.521005, 119.641554)        29 C
# 3  2025-06-02T21:36:32I3     PKG004  (10.941567, 118.303819)        29 C
# 4  2025-06-02T21:36:32I4     PKG005   (9.844815, 118.509812)        29 C
#
#        status
# 0   Delivered
# 1   Delivered
# 2     Delayed
# 3   Delivered
# 4  In Transit
# ✅ Connected to Ganache successfully!
# ✅ Connected to Smart Contract at 0xd031B8de5e372d5c40040c93e387c4240350B7bF
# ✅ Data Stored PKG001 GPS:  (7.839114, 125.820784) Temp: 29 C  Status: Delivered  at block   2 Txn hash b6ca0f7550a36ec2952550945f9317c1e6f1df88b9a456de26413f565178f86d
# ✅ Data Stored PKG002 GPS: (16.754497, 116.599905) Temp: 24 C  Status: Delivered  at block   3 Txn hash df5fd87cb1bce331f33984546db4cf3ffd6a4a72eb02e4908d9e3288dea0a7ca
# ✅ Data Stored PKG003 GPS: (16.521005, 119.641554) Temp: 29 C  Status: Delayed    at block   4 Txn hash bc0c79cd6e1ddb1c1d2edd7c55b92b0fcec4ba856d598b92ff53b59d9bd146dc
# ✅ Data Stored PKG004 GPS: (10.941567, 118.303819) Temp: 29 C  Status: Delivered  at block   5 Txn hash f58cfcfd04752ce290c7cc03a5f68595bddfe84fd581bd1bc9c1599f8924c0b5
# ✅ Data Stored PKG005 GPS:  (9.844815, 118.509812) Temp: 29 C  Status: In Transit at block   6 Txn hash 34528c9cc774dcfa31dff79bff446f68b50d75df8224323d93476ae65fac5987
# ✅ Data Stored PKG006 GPS:   (8.86805, 120.813762) Temp: 30 C  Status: Delivered  at block   7 Txn hash 9ba981424e6dac048aaaaf4d46744988448a953cbd3a86027d224ec518b64324
# ✅ Data Stored PKG007 GPS: (12.741756, 118.439917) Temp: 27 C  Status: In Transit at block   8 Txn hash 756dc17349bd1261516bfb2464d4e3996eb1e468fadb17271dba101f2a23364c
# ✅ Data Stored PKG008 GPS: (15.501252, 122.082088) Temp: 29 C  Status: Delivered  at block   9 Txn hash a35ab37c791f34965daffe250ecaf1206e369cdad9dcd50f990273af1ac6ceb5
# ✅ Data Stored PKG009 GPS:  (8.443512, 118.729713) Temp: 27 C  Status: In Transit at block  10 Txn hash e0c0aabc9415079d89877ee708ba1191d3b591f7e6fe8e91a98998feb556253e
# ✅ Data Stored PKG010 GPS:  (7.319699, 126.018423) Temp: 24 C  Status: Delayed    at block  11 Txn hash c900398d719bd1bbff7a5d8eb1e8fd7a733dea91d35dec33b79c625b964d6543
# ✅ Data Stored PKG011 GPS: (17.975589, 121.024438) Temp: 30 C  Status: Delivered  at block  12 Txn hash 7744331e9ad102668fac34be2c9cd2b393fccb28a059e25b95307f47a5619751
# ✅ Data Stored PKG012 GPS: (20.895582, 116.357231) Temp: 24 C  Status: Delivered  at block  13 Txn hash 6f54a03d8499078404d57c7526d4e3b981cbe01e41cde40a6948a4eda2670bd4
# ✅ Data Stored PKG013 GPS:  (13.937566, 122.10715) Temp: 27 C  Status: Delayed    at block  14 Txn hash 4169a6534463c8220da7dad2f86a8b83fd0329a6fb159e04db007899d82bba3e
# ✅ Data Stored PKG014 GPS: (16.165907, 121.608117) Temp: 26 C  Status: Delayed    at block  15 Txn hash 30ff6105ec65ad6acc1c1bc732d3d46dcb88990ebc4900625a42f344eb789af1
# ✅ Data Stored PKG015 GPS: (16.311307, 118.017979) Temp: 27 C  Status: Delivered  at block  16 Txn hash 39845ebef750c68bcd672f75236e1bc6ee897b14e86e54aba4285d627b5fc6f2
# ✅ Data Stored PKG016 GPS:  (5.390759, 125.643993) Temp: 24 C  Status: Delayed    at block  17 Txn hash b32acba3be1ce91b3d5af4babc4be480026266d3c4092f0a90105ad21adc3292
# ✅ Data Stored PKG017 GPS: (12.625246, 125.616081) Temp: 25 C  Status: Delayed    at block  18 Txn hash a2376511c1da0dc2abcf73e4875179fa87a2aa7866818f85e937f29f87ddd48b
# ✅ Data Stored PKG018 GPS: (14.156132, 124.678982) Temp: 26 C  Status: In Transit at block  19 Txn hash 7256c948036e7ecb9c959bf7dba16742665cac3c9a71a6700238a76de4149c86
# ✅ Data Stored PKG019 GPS: (19.627461, 121.054452) Temp: 29 C  Status: Delivered  at block  20 Txn hash 0ae01c5f18e522fcec3610c4a523766e94f50f35bc3065b7a9f915e0253647bf
# ✅ Data Stored PKG020 GPS:   (15.419375, 119.4685) Temp: 24 C  Status: Delayed    at block  21 Txn hash 88e24b76143f02066fa4e34c4193ccce153ed679efbfa1b57b5ba1f835773920
# ✅ Data Stored PKG021 GPS: (11.712474, 119.182333) Temp: 27 C  Status: In Transit at block  22 Txn hash 9d21ce9fac47ff080702a7631eb5249628a1a14ab91febacb46fd53d0d3e1d3a
# ✅ Data Stored PKG022 GPS:  (8.105608, 118.457009) Temp: 30 C  Status: In Transit at block  23 Txn hash 98f048af604e2446f8506b4e9aa464660e99a46800589fd842ded1eb5c0a34f3
# ✅ Data Stored PKG023 GPS:  (6.418801, 119.158313) Temp: 27 C  Status: Delivered  at block  24 Txn hash f62c77a6a883101a38e0dc539c96bf0b9331121e7013aa9b2cbc64447c1a37e1
# ✅ Data Stored PKG024 GPS: (11.360729, 124.448003) Temp: 30 C  Status: In Transit at block  25 Txn hash a688b268ad41ee3b81892ce469f495b1cbb2bfabdca909cc17342bfacf72b08a
# ✅ Data Stored PKG025 GPS:  (7.264897, 117.127706) Temp: 24 C  Status: Delivered  at block  26 Txn hash 80cb64602f07cfdeeefa8d31245c580dfaa2b82c1c7c0d3c46a62358ca9f5629
# ✅ Data Stored PKG026 GPS:  (8.098239, 121.392044) Temp: 27 C  Status: In Transit at block  27 Txn hash 0ecb6a101548dfd2a4492f33c8bf18686a5620f4c187e760e81af21003a6a8c8
# ✅ Data Stored PKG027 GPS:  (8.625353, 123.941422) Temp: 25 C  Status: Delivered  at block  28 Txn hash a1bd73f299205da56b1794c07a4daca9e7a91fafcd32bc16408fbadfa9f43b51
# ✅ Data Stored PKG028 GPS: (15.677987, 123.517964) Temp: 26 C  Status: In Transit at block  29 Txn hash f52b369ca2db5869ecef8bb610f5cba72a9e3ba40252e5b4bca59e78f86f62dc
# ✅ Data Stored PKG029 GPS: (17.602117, 123.518825) Temp: 26 C  Status: Delivered  at block  30 Txn hash 8b3ff06ce343db0e5e0e57c2512f17fb1dd0742398eb62745e803047c9e92d22
# ✅ Data Stored PKG030 GPS: (12.054201, 116.765579) Temp: 26 C  Status: Delayed    at block  31 Txn hash 1354ee005a9e725cce0011e19fd31be69b973c3749cc12a52f29137dd60e4afa
# ✅ Data Stored PKG031 GPS: (10.820827, 125.110851) Temp: 27 C  Status: Delayed    at block  32 Txn hash b86bff065808080eb1ab35d1b40abdb030ce20890e68ec3083a51b97eb08ac7d
# ✅ Data Stored PKG032 GPS:   (6.981207, 123.79629) Temp: 30 C  Status: In Transit at block  33 Txn hash eb0f0df27c9f259618c47e09d946df77ac17c7fdf7af1f56909904c2efb2cbf5
# ✅ Data Stored PKG033 GPS: (20.348736, 123.021186) Temp: 28 C  Status: Delayed    at block  34 Txn hash 4cd5021b9ba0b28491091e84a9390611967d3b375e22c6af7f5d743fd62e9a06
# ✅ Data Stored PKG034 GPS:  (7.625714, 123.111139) Temp: 28 C  Status: In Transit at block  35 Txn hash 4ff1873263b7899900403f9f2dfb7473487717a1b13835c66417dd2a02c413c2
# ✅ Data Stored PKG035 GPS:  (9.426897, 125.750272) Temp: 24 C  Status: In Transit at block  36 Txn hash 27667fcae33fd3e3eb818dace0958675cc9d13e0d68580eab6fa48f31d9a9e0a
# ✅ Data Stored PKG036 GPS:  (9.703381, 117.062399) Temp: 26 C  Status: Delayed    at block  37 Txn hash 2f9606fc16de311ed196af0f8961f79fb407ef405f6c0bbf311cc2cf91988535
# ✅ Data Stored PKG037 GPS:  (19.694293, 125.22267) Temp: 26 C  Status: In Transit at block  38 Txn hash c1a81b014cb70e5df7d2fda79fd48db04e146c2b7e34abe666d2e4cd41b155f2
# ✅ Data Stored PKG038 GPS: (15.375615, 123.952056) Temp: 27 C  Status: In Transit at block  39 Txn hash 2775693da722664ac805feb1b47efa864405d2a9e64202156a4445411c389256
# ✅ Data Stored PKG039 GPS: (18.475301, 121.448325) Temp: 28 C  Status: In Transit at block  40 Txn hash 7b6aed97028c6ad8af52ecc2fead1818f66e31e5d16fc3d5cb24a2dc8a677a37
# ✅ Data Stored PKG040 GPS:  (16.58086, 123.536357) Temp: 28 C  Status: Delayed    at block  41 Txn hash 5a3aa5e400453c73f903f10bd564229a9ef18944065f2c83b7e2aabc44df3004
# ✅ Data Stored PKG041 GPS: (13.563926, 126.967492) Temp: 29 C  Status: Delayed    at block  42 Txn hash ce09068efa76f4ad1a5ec66fd78c6fb28e4bc2015859a73d7d1599c61af983eb
# ✅ Data Stored PKG042 GPS:  (19.480452, 116.36425) Temp: 27 C  Status: In Transit at block  43 Txn hash 2b5c8b79b75852d2dea81480d549a0f29fa318cd4666f9fab93a95524c60c867
# ✅ Data Stored PKG043 GPS: (11.194763, 124.513853) Temp: 27 C  Status: Delayed    at block  44 Txn hash 0637f6482a8bf0b030a4c4fb0791ec67a8202a2f238a86e3eb17b768709754df
# ✅ Data Stored PKG044 GPS:  (8.178935, 118.121624) Temp: 24 C  Status: Delivered  at block  45 Txn hash e9325935363f4ae1d40c0aa12d6422d8856ad9ff9c67fe65ee07cdbe1c610fa6
# ✅ Data Stored PKG045 GPS:  (11.680432, 124.44445) Temp: 24 C  Status: In Transit at block  46 Txn hash 51f17cd98ddf1f973be49386c28583ab78fb42ac9778aac7f0315e028845a835
# ✅ Data Stored PKG046 GPS: (15.771875, 122.903814) Temp: 28 C  Status: Delayed    at block  47 Txn hash c8207ecdff65b84256aadd994c632ae26252be435690bda02a708283b779de0b
# ✅ Data Stored PKG047 GPS: (12.040084, 116.369242) Temp: 27 C  Status: In Transit at block  48 Txn hash e260a2a5eb7374e6bed732b053bfd5663c3a209530317b7bf7936ecdcf42baa1
# ✅ Data Stored PKG048 GPS: (14.732945, 121.222389) Temp: 29 C  Status: In Transit at block  49 Txn hash 55eceb85b1e9b876709234b58e1919e74cfc49fa20c2d2e5439db85f50baf3d2
# ✅ Data Stored PKG049 GPS: (11.035818, 118.615475) Temp: 28 C  Status: Delivered  at block  50 Txn hash fcf4c866d85054ab362ed5d365a4f106076bdb726ecabf621c19a6ea900f2f1d
# ✅ Data Stored PKG050 GPS: (10.548708, 126.350368) Temp: 26 C  Status: In Transit at block  51 Txn hash b8a8ab5edcc45aab27f58bd039cadadebf6583618333a1259129c8d4a1dc3cea
# ✅ Data Stored PKG051 GPS: (13.914717, 116.106482) Temp: 30 C  Status: Delayed    at block  52 Txn hash dba85e109267f14fbecda2c031ca3fad727c8eb45d557145914bfc6d368852c4
# ✅ Data Stored PKG052 GPS: (14.597959, 125.412033) Temp: 27 C  Status: In Transit at block  53 Txn hash 50bf520b5dc0bcbfd3ab84e4e21ce7e315304a5712efa21383c9c64a9dff77fc
# ✅ Data Stored PKG053 GPS: (20.834108, 120.921661) Temp: 26 C  Status: Delivered  at block  54 Txn hash 8bfe2d81954d016fb7fc3f57a83d49e3631e32e4f5e93791be8f632dc8f4ad2f
# ✅ Data Stored PKG054 GPS:   (9.231447, 122.26437) Temp: 30 C  Status: In Transit at block  55 Txn hash f1f75b43a1fadf5de08063be8d25c9b1c6f6c7ef6a64e29ec7c5ff69178b067e
# ✅ Data Stored PKG055 GPS:  (4.505109, 116.363897) Temp: 24 C  Status: In Transit at block  56 Txn hash c619a34a4602079eee23f522aa4246bd2a258bed0e3eb0ee4f72caa2135c1bc7
# ✅ Data Stored PKG056 GPS: (14.097964, 116.040866) Temp: 27 C  Status: In Transit at block  57 Txn hash a2d88d8c05f50410d6b00cff1be2d8a77ff129bee4cfabc802929de26cacfe35
# ✅ Data Stored PKG057 GPS:  (17.949557, 119.85132) Temp: 24 C  Status: Delayed    at block  58 Txn hash 6ba44952c185973720e076983fd4d3a984d3c70a1e272db6468814539a17a79e
# ✅ Data Stored PKG058 GPS:  (5.844681, 124.776239) Temp: 27 C  Status: Delivered  at block  59 Txn hash 8e965e7f3f8b8d0f1c7b752ea974fb7bfe6b161c51227fae5f6a9f3990ebdb1c
# ✅ Data Stored PKG059 GPS:  (7.631688, 116.979815) Temp: 25 C  Status: Delayed    at block  60 Txn hash 43970fcc9ae00fb727bad1f013532329460494e0385ad9947b8ff77913a517b7
# ✅ Data Stored PKG060 GPS:  (8.679544, 120.659995) Temp: 24 C  Status: Delayed    at block  61 Txn hash 501510109cc18d0aa0e16f7a4cf2574d44608328c6cae70c2c7c3a817206a3b3
# ✅ Data Stored PKG061 GPS: (19.975022, 124.454962) Temp: 24 C  Status: Delivered  at block  62 Txn hash 59a8dd02e405496c4c7e5ab658286a82ef4c291322f25fc1ee77810c2b981cf0
# ✅ Data Stored PKG062 GPS: (11.411139, 116.574568) Temp: 28 C  Status: Delivered  at block  63 Txn hash 1151536cb7b3c7f6eca724082f53c5f5606f222d7392a893ba1a3691dd088218
# ✅ Data Stored PKG063 GPS:   (4.537106, 120.18287) Temp: 29 C  Status: Delivered  at block  64 Txn hash dd44add1c41ecdd5266b63f8474eb1f088620580a12978e07d409794f3354b42
# ✅ Data Stored PKG064 GPS:   (7.939288, 124.22867) Temp: 25 C  Status: In Transit at block  65 Txn hash 1564d66f8f282af24c2bcaa80c13b75449ba1daa959eb5e4e7a44a2d8a31f8a7
# ✅ Data Stored PKG065 GPS:  (7.082617, 116.000626) Temp: 27 C  Status: Delayed    at block  66 Txn hash b1667004dd52c5e6db4ddd14fa016ac24b7e99b63f03a1bce24b49e41414b492
# ✅ Data Stored PKG066 GPS: (10.838625, 117.070254) Temp: 29 C  Status: Delayed    at block  67 Txn hash 9558a7f5994220d0e2a8a04d0d1446e10977d2ae223e0d44dd3c8d1d2d301267
# ✅ Data Stored PKG067 GPS:    (8.899587, 116.0402) Temp: 27 C  Status: Delivered  at block  68 Txn hash 3bf54318ae3a1e0f4cc29eb07b670dd6657d3fc17233f0f58a4c7d9aa90f456c
# ✅ Data Stored PKG068 GPS:  (7.145796, 118.263733) Temp: 26 C  Status: Delayed    at block  69 Txn hash ca46aec4ca1f2bf089cc158e42fec89f312c9087c8aeb6b7f81c0e5c5d550e87
# ✅ Data Stored PKG069 GPS: (20.308394, 123.106085) Temp: 28 C  Status: Delayed    at block  70 Txn hash 3e9ad32d13efb9071389afd5c4341458c15aa5eab93cac6b32795052a442992b
# ✅ Data Stored PKG070 GPS:  (5.709838, 125.649678) Temp: 28 C  Status: In Transit at block  71 Txn hash 8f571dbf3328e8121938f051b41a9b8867fb519890ee355321895c148915a239
# ✅ Data Stored PKG071 GPS:  (6.839736, 123.498628) Temp: 29 C  Status: Delayed    at block  72 Txn hash c8eadd88ef00116cd7cb99c2d64bc044a6d450a952dbd289ff62c4ffc72443a0
# ✅ Data Stored PKG072 GPS: (13.995788, 126.724895) Temp: 26 C  Status: In Transit at block  73 Txn hash 01f36265a4053b56fb02e21dba90695eb969526818f40172ac21ad42c1576ab5
# ✅ Data Stored PKG073 GPS:  (9.465027, 116.899757) Temp: 24 C  Status: Delivered  at block  74 Txn hash 719c17665603e62b3e42b70889d1388622f109a709ca8536e5c4c4f86239ee37
# ✅ Data Stored PKG074 GPS:  (5.740364, 123.984693) Temp: 24 C  Status: In Transit at block  75 Txn hash bef07d38977fe027ba7c759ab67cbf4b387a34742e705b8b54a6d40e5d1138f4
# ✅ Data Stored PKG075 GPS:  (7.041248, 122.272286) Temp: 27 C  Status: Delayed    at block  76 Txn hash a1af1773e40a5a38e59c678e1b1b243099c11e57cbb6f439357e1863e40a00fc
# ✅ Data Stored PKG076 GPS: (18.078201, 118.168643) Temp: 27 C  Status: In Transit at block  77 Txn hash f1303577489d1f2d32bf132c49587115019fc77f8caf55624362943b46711440
# ✅ Data Stored PKG077 GPS: (20.868882, 119.887165) Temp: 24 C  Status: Delayed    at block  78 Txn hash 5adea860eecfc4a995fe43c2198db2048a7d67e35ecdfdde45b70e422787eeab
# ✅ Data Stored PKG078 GPS: (11.530742, 117.739627) Temp: 27 C  Status: Delayed    at block  79 Txn hash 6ebc3da4788be89541a02d6694cba630e5c058031d2d92f51a3c832148754487
# ✅ Data Stored PKG079 GPS: (14.155735, 122.167592) Temp: 24 C  Status: Delivered  at block  80 Txn hash de1c8478599916d8ea5975ae3ce0ff83e6c52d0ee22635e5442fff44f1fb4531
# ✅ Data Stored PKG080 GPS:  (5.745231, 116.345228) Temp: 25 C  Status: In Transit at block  81 Txn hash d85c60e6c02039734d047577d1f53bc57d14612dc3de7058e84722f4e57e4656
# ✅ Data Stored PKG081 GPS: (13.299741, 124.639463) Temp: 25 C  Status: Delayed    at block  82 Txn hash cc0b1452bcb02dcf0012e1316f5edd4481c71977a433150380c9a0fe51606cac
# ✅ Data Stored PKG082 GPS:  (17.439801, 125.83448) Temp: 29 C  Status: In Transit at block  83 Txn hash 0da76d8df6ebc75b065a5e730604f63f0342cf4ee75e24ee2228b38b6f396067
# ✅ Data Stored PKG083 GPS:  (5.517328, 118.667595) Temp: 25 C  Status: In Transit at block  84 Txn hash d81b532a32e41edd41f1fd6075ba0dc2c31361e5e1422411a06b5e3a1dd9f10d
# ✅ Data Stored PKG084 GPS: (19.391768, 118.548733) Temp: 28 C  Status: In Transit at block  85 Txn hash 8a4997ddee37c5d1db5ff232204a88cc17e8bd9e161152cb26f68b1b278b1d9c
# ✅ Data Stored PKG085 GPS: (17.220957, 126.098216) Temp: 27 C  Status: Delayed    at block  86 Txn hash cbc7a35884451f0dc85281e51b11b696f2301fea78260588cfc0feacb54eb0eb
# ✅ Data Stored PKG086 GPS:  (7.731702, 117.299307) Temp: 25 C  Status: In Transit at block  87 Txn hash 8e785cb6e26d41167700f82b7ea1b40e8c77f43fdd4b75a7cc5dc96edad35c02
# ✅ Data Stored PKG087 GPS:  (5.563162, 125.435676) Temp: 25 C  Status: In Transit at block  88 Txn hash 5b699b316c84f7dbd3b0903a0175461329aed26b1551c13bbfa6917eeb9ac464
# ✅ Data Stored PKG088 GPS:  (7.023184, 121.483225) Temp: 25 C  Status: Delayed    at block  89 Txn hash b79f70692a2e709c47e6b8cc6e5f60cea7e8c532a5ff29ac06ae94ea35256092
# ✅ Data Stored PKG089 GPS: (14.735133, 116.891753) Temp: 28 C  Status: Delivered  at block  90 Txn hash 4aba937202a1072b5ae17656092a7526561ff693e26bcae61e692ad9b5076eb6
# ✅ Data Stored PKG090 GPS: (10.266517, 124.031933) Temp: 27 C  Status: Delivered  at block  91 Txn hash 65f2275a809a703deea43809ea23d5097af6f5a686e10f771fa62a34c8024a8f
# ✅ Data Stored PKG091 GPS:  (19.872964, 123.86125) Temp: 27 C  Status: In Transit at block  92 Txn hash fa69af296317853632f6b59badf2ace9aa8321c3b55c97532e78d8d73987d8ed
# ✅ Data Stored PKG092 GPS: (14.481173, 117.737989) Temp: 28 C  Status: In Transit at block  93 Txn hash e4ed308d939bf4164b7b9a68b02ed3038e0d2a85c320d258bf80f02d90930eeb
# ✅ Data Stored PKG093 GPS: (16.730197, 118.481903) Temp: 24 C  Status: In Transit at block  94 Txn hash b1227b1c206062db931699c348142322863d9ef4f8f5654278fea3ccd9ebaf51
# ✅ Data Stored PKG094 GPS: (12.760738, 117.442269) Temp: 26 C  Status: In Transit at block  95 Txn hash c4eaeadf1a8837b2272418cb03b975590edc6096d56039ff3b680e00de853718
# ✅ Data Stored PKG095 GPS:   (6.622769, 125.03202) Temp: 25 C  Status: Delivered  at block  96 Txn hash 17ad4db5b2dd571d766e98ad96fb71d2852ef4f9a15ce144263db2ac2fa5c1ba
# ✅ Data Stored PKG096 GPS: (12.998725, 125.744701) Temp: 28 C  Status: Delayed    at block  97 Txn hash 4931a385386397001fcc103880f9728df4f731992473da8813063776a442c00f
# ✅ Data Stored PKG097 GPS:  (20.336235, 126.65279) Temp: 27 C  Status: Delayed    at block  98 Txn hash 3316f3b79a895933ef2152516ede432e8c64c3f1adc756426802d9c4418721fa
# ✅ Data Stored PKG098 GPS:  (8.659069, 126.519407) Temp: 26 C  Status: Delayed    at block  99 Txn hash e763d4fd156e11a75f52e9a3962e6ad85150cb8f730bfb8de323ce5c61320cf4
# ✅ Data Stored PKG099 GPS:  (9.128521, 123.681135) Temp: 24 C  Status: Delayed    at block 100 Txn hash 7326c470141b03e40a1d78bad8d71c74e212698fd90172ad81b1d81a2623a95a
# ✅ Data Stored PKG100 GPS:  (8.911339, 126.627085) Temp: 27 C  Status: Delayed    at block 101 Txn hash 2cbd9ee8d63851bee3720175f78e124fa0264b4591c63669d93ead49bb72d7ea
# Total IoT records stored: 100
# First Stored Record : [1749454916, 'PKG001', '(7.839114, 125.820784)', '29 C', 'Delivered']

# %%
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 100

# %%
import pandas as pd
import numpy as np

# Retrieve all IoT records from the blockchain
iot_records = [] 

# Convert the stored data back to a DataFrame for easy viewing
total_records = contract.functions.getTotalRecords().call()    
for i in range(total_records):
    record = contract.functions.getRecord(i).call()
    iot_records.append({
        "timestamp"  : record[0],
        "package_id" : record[1],
        "gps_coords" : record[2],
        "temperature": record[3],
        "status"     : record[4]
    })
        
# Covert to a DataFrame
iot_df = pd.DataFrame(iot_records)

# Convert timestamp to a readable format
iot_df['timestamp'] = pd.to_datetime(iot_df['timestamp'], unit='s')

# Display the DataFrame
print(iot_df.head())
# Out:
#             timestamp package_id               gps_coords temperature  \
# 0 2025-06-09 07:41:56     PKG001   (7.839114, 125.820784)        29 C
# 1 2025-06-09 07:41:57     PKG002  (16.754497, 116.599905)        24 C
# 2 2025-06-09 07:41:58     PKG003  (16.521005, 119.641554)        29 C
# 3 2025-06-09 07:41:59     PKG004  (10.941567, 118.303819)        29 C
# 4 2025-06-09 07:42:00     PKG005   (9.844815, 118.509812)        29 C
#
#        status
# 0   Delivered
# 1   Delivered
# 2     Delayed
# 3   Delivered
# 4  In Transit

# %%
import numpy as np


'''
Longitude and latitude are the coordinates used to pinpoint locations on Earth's surface. 
They create a grid system that allows precise positioning.

Latitude - measures how far north or south a place is from the Equator. 
    It’s expressed in degrees (°) from 0° at the Equator up to 90° at the poles.

Longitude - measures how far east or west a place is from the Prime Meridian, which is 0° longitude. 
    It extends up to 180° east or west.

Example for the Philippines:
Metro Manila, the capital region, has coordinates approximately:
Latitude: 14.5995° N (north of the Equator)
Longitude: 120.9842° E (east of the Prime Meridian)

Every place in the world has a unique set of longitude and latitude coordinates—kind of like a GPS address for locations! 

The coordinates 7.839114, 125.820784 are in "decimal degrees (DD)" format, and 
they have been converted into "degrees, minutes, and seconds (DMS)" format. 

Here’s how the conversion works:

1. Latitude: 7.839114° N
   - The whole number 7 is the degrees (°).
   - Multiply the decimal part (0.839114) by 60 to get minutes:
     - 0.839114 × 60 = 50.347 → 50 minutes (keep the decimal part for seconds).
   - Multiply the remaining decimal (0.347) by 60 to get seconds:
     - 0.347 × 60 = 20.8 → 20.8 seconds.
   - Final latitude in DMS: 7°50'20.8" N.

2. Longitude: 125.820784° E
   - The whole number 125 is the degrees (°).
   - Multiply the decimal part (0.820784) by 60 to get minutes:
     - 0.820784 × 60 = 49.247 → 49 minutes.
   - Multiply the remaining decimal (0.247) by 60 to get seconds:
     - 0.247 × 60 = 14.8 → 14.8 seconds.
   - Final longitude in DMS: 125°49'14.8" E.

So, 7.839114, 125.820784 (DD) → 7°50'20.8" N, 125°49'14.8" E (DMS). 

This conversion is useful when working with traditional navigation systems or maps. 
'''

# Extract numeric values from 'data_value' where applicable
iot_df["temp_in_celsius"] = iot_df["temperature"].str.extract(r'(\d+\.?\d*)').astype(float)
yx_coords = iot_df["gps_coords"].str.split(', ', expand=True)
print(yx_coords)

# Extract latitude and longitude from 'gps_coords'
iot_df["latitude"] = iot_df["gps_coords"].str.extract(r'(\d+\.?\d*)').astype(float)
iot_df["longitude"] = iot_df["gps_coords"].str.extract(r'(\d+\.?\d*)').astype(float)


# Handle missing values (if any)
iot_df.fillna(0, inplace=True)


# Display cleaned data
print(iot_df.head())
# Out:
#              0            1
# 0    (7.839114  125.820784)
# 1   (16.754497  116.599905)
# 2   (16.521005  119.641554)
# 3   (10.941567  118.303819)
# 4    (9.844815  118.509812)
# ..         ...          ...
# 95  (12.998725  125.744701)
# 96  (20.336235   126.65279)
# 97   (8.659069  126.519407)
# 98   (9.128521  123.681135)
# 99   (8.911339  126.627085)
#
# [100 rows x 2 columns]
#             timestamp package_id               gps_coords temperature  \
# 0 2025-06-09 07:41:56     PKG001   (7.839114, 125.820784)        29 C
# 1 2025-06-09 07:41:57     PKG002  (16.754497, 116.599905)        24 C
# 2 2025-06-09 07:41:58     PKG003  (16.521005, 119.641554)        29 C
# 3 2025-06-09 07:41:59     PKG004  (10.941567, 118.303819)        29 C
# 4 2025-06-09 07:42:00     PKG005   (9.844815, 118.509812)        29 C
#
#        status  temp_in_celsius   latitude  longitude
# 0   Delivered             29.0   7.839114   7.839114
# 1   Delivered             24.0  16.754497  16.754497
# 2     Delayed             29.0  16.521005  16.521005
# 3   Delivered             29.0  10.941567  10.941567
# 4  In Transit             29.0   9.844815   9.844815

# %%
# Save cleaned IoT data to a CSV file
iot_df.to_csv("cleaned_iot_data.csv", index=False)


print("✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv")
# Out:
# ✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv
