# %%
# Week 5 - Milestone 1: Smart Tracking System Blockchain Ledger (Submission)

# This script is intended to be run in a Jupyter Notebook environment.
# To run this script, ensure you have Jupyter Notebook installed and running.

# You can install Jupyter Notebook using pip:
# %pip install notebook

# You can start Jupyter Notebook by running the following command in your terminal:
# $ jupyter notebook 

# This script connects to a local Ganache blockchain using Web3.py.
# Make sure you have Ganache running and Web3.py installed.
# %pip install web3

from web3 import Web3
import json, time


# Load CSV file from your Homework 1
import pandas as pd


# Load IoT sensor data from CSV file (Generated in Homework 1)
df = pd.read_csv('../Week 5 Homework/iot_data.csv')

# Display the first few rows of the DataFrame
print(df.head())

# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

# Check if connected to Ganache
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
    exit()

# Replace with actual contract address form Remix 
contract_address = "0x3e11716EA63F4dD951DFe30516F99597daD79Dc2"

# Paste the ABI from Remix 
# abi = [...] # Replace with the actual ABI of your contract

# If you have the ABI in a file, you can load it like this:
with open('copy-of-abi.json', 'r') as abi_file:
    abi = json.load(abi_file)

# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)

# Set the default sender address (the first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")


# Send the IoT data to the blockchain. Each row from the CSV file will be stored as a transaction on the blockchain.
def send_iot_data(package_id, gps_coords, temperature, status):
    
    txn = contract.functions.storeData(
        package_id,
        gps_coords,
        temperature,
        status
    ).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
    
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Data Stored {package_id} GPS: {gps_coords:>23} Temp: {temperature}  Status: {status:<10} at block {
        receipt.blockNumber:>3} Txn hash {receipt.transactionHash.hex()}")


# Iterate through the DataFrame and send each row to the blockchain
for index, row in df.iterrows():

    package_id  = str(row['package_id'  ])
    gps_coords  = str(row['gps_coords'  ])
    temperature = str(row['temperature' ])
    status      = str(row['status'      ])    

    send_iot_data(package_id, gps_coords, temperature, status)    
    time.sleep(1)  # sleep to avoid hitting the gas limit too quickly

# now that the data is on the blockchain, we can retrieve it to verify storage
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")

# retrieve and print a specific record (e.g., the first one)
record = contract.functions.getRecord(0).call()
print(f"First Stored Record : {record}")
# Out:
#                timestamp package_id               gps_coords temperature  \
# 0  2025-06-02T21:36:32I0     PKG001   (7.839114, 125.820784)        29 C
# 1  2025-06-02T21:36:32I1     PKG002  (16.754497, 116.599905)        24 C
# 2  2025-06-02T21:36:32I2     PKG003  (16.521005, 119.641554)        29 C
# 3  2025-06-02T21:36:32I3     PKG004  (10.941567, 118.303819)        29 C
# 4  2025-06-02T21:36:32I4     PKG005   (9.844815, 118.509812)        29 C
#
#        status
# 0   Delivered
# 1   Delivered
# 2     Delayed
# 3   Delivered
# 4  In Transit
# ✅ Connected to Ganache successfully!
# ✅ Connected to Smart Contract at 0x3e11716EA63F4dD951DFe30516F99597daD79Dc2
# ---------------------------------------------------------------------------
# Web3RPCError                              Traceback (most recent call last)
# Cell In[9], line 85
#      82     temperature = str(row['temperature' ])
#      83     status      = str(row['status'      ])
# ---> 85     send_iot_data(package_id, gps_coords, temperature, status)
#      86     time.sleep(1)  # Sleep to avoid hitting the gas limit too quickly
#      88 # now that the data is on the blockchain, we can retrieve it to verify storage
#
# Cell In[9], line 68, in send_iot_data(package_id, gps_coords, temperature, status)
#      61 def send_iot_data(package_id, gps_coords, temperature, status):
#      63     txn = contract.functions.storeData(
#      64         package_id,
#      65         gps_coords,
#      66         temperature,
#      67         status
# ---> 68     ).transact({
#      69         'from': web3.eth.default_account,
#      70         'gas': 3000000
#      71     })
#      73     receipt = web3.eth.wait_for_transaction_receipt(txn)
#      74     print(f"✅ Data Stored {package_id} GPS: {gps_coords:>23} Temp: {temperature}  Status: {status:<10} at block {
#      75         receipt.blockNumber:>3} Txn hash {receipt.transactionHash.hex()}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\web3\contract\contract.py:311, in ContractFunction.transact(self, transaction)
#     308 setup_transaction = self._transact(transaction)
#     309 abi_element_identifier = abi_to_signature(self.abi)
# --> 311 return transact_with_contract_function(
#     312     self.address,
#     313     self.w3,
#     314     abi_element_identifier,
#     315     setup_transaction,
#     316     self.contract_abi,
#     317     self.abi,
#     318     *self.args or (),
#     319     **self.kwargs or {},
#     320 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\web3\contract\utils.py:265, in transact_with_contract_function(address, w3, abi_element_identifier, transaction, contract_abi, fn_abi, *args, **kwargs)
#     250 """
#     251 Helper function for interacting with a contract function by sending a
#     252 transaction.
#     253 """
#     254 transact_transaction = prepare_transaction(
#     255     address,
#     256     w3,
#    (...)
#     262     fn_kwargs=kwargs,
#     263 )
# --> 265 txn_hash = w3.eth.send_transaction(transact_transaction)
#     266 return txn_hash
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\web3\eth\eth.py:387, in Eth.send_transaction(self, transaction)
#     386 def send_transaction(self, transaction: TxParams) -> HexBytes:
# --> 387     return self._send_transaction(transaction)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\web3\module.py:112, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#     105     return LogFilter(eth_module=module, filter_id=err.filter_id)
#     107 (
#     108     result_formatters,
#     109     error_formatters,
#     110     null_result_formatters,
#     111 ) = response_formatters
# --> 112 result = w3.manager.request_blocking(
#     113     method_str, params, error_formatters, null_result_formatters
#     114 )
#     115 return apply_result_formatters(result_formatters, result)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\web3\manager.py:232, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     228 """
#     229 Make a synchronous request using the provider
#     230 """
#     231 response = self._make_request(method, params)
# --> 232 return self.formatted_response(
#     233     response, params, error_formatters, null_result_formatters
#     234 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\web3\manager.py:198, in RequestManager.formatted_response(self, response, params, error_formatters, null_result_formatters)
#     184 def formatted_response(
#     185     self,
#     186     response: RPCResponse,
#    (...)
#     189     null_result_formatters: Optional[Callable[..., Any]] = None,
#     190 ) -> Any:
#     191     is_subscription_response = (
#     192         response.get("method") == "eth_subscription"
#     193         and response.get("params") is not None
#     194         and response["params"].get("subscription") is not None
#     195         and response["params"].get("result") is not None
#     196     )
# --> 198     validate_rpc_response_and_raise_if_error(
#     199         response,
#     200         error_formatters,
#     201         is_subscription_response=is_subscription_response,
#     202         logger=self.logger,
#     203         params=params,
#     204     )
#     206     # format results
#     207     if "result" in response:
#     208         # Null values for result should apply null_result_formatters
#     209         # Skip when result not present in the response (fallback to False)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\web3\_utils\validation.py:401, in validate_rpc_response_and_raise_if_error(response, error_formatters, is_subscription_response, logger, params)
#     398     if logger is not None:
#     399         logger.debug("RPC error response: %s", response)
# --> 401     raise web3_rpc_error
#     403 elif "result" not in response and not is_subscription_response:
#     404     _raise_bad_response_format(response)
#
# Web3RPCError: {'message': 'VM Exception while processing transaction: revert Storage limit reached', 'stack': 'RuntimeError: VM Exception while processing transaction: revert Storage limit reached\n    at EIP1559FeeMarketTransaction.fillFromResult (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:12745)\n    at Miner.<anonymous> (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:36703)\n    at async Miner.<anonymous> (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:35116)\n    at async Miner.mine (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:39680)\n    at async Blockchain.mine (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:60063)\n    at async Promise.all (index 0)\n    at async TransactionPool.emit (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\node_modules\\emittery\\index.js:303:3)', 'code': -32000, 'name': 'RuntimeError', 'data': {'hash': '0x600c75df0e6e8e4573e5a88a4aaa179a247e98adff618330a49ed6ba35f16172', 'programCounter': 1357, 'result': '0x600c75df0e6e8e4573e5a88a4aaa179a247e98adff618330a49ed6ba35f16172', 'reason': 'Storage limit reached', 'message': 'revert'}}
