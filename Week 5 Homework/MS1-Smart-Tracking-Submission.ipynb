# %%
# Week 5 - Milestone 1: Smart Tracking System Blockchain Ledger (Submission)

# This script is intended to be run in a Jupyter Notebook environment.
# To run this script, ensure you have Jupyter Notebook installed and running.

# You can install Jupyter Notebook using pip:
# %pip install notebook

# You can start Jupyter Notebook by running the following command in your terminal:
# $ jupyter notebook 

# This script connects to a local Ganache blockchain using Web3.py.
# Make sure you have Ganache running and Web3.py installed.
# %pip install web3

from web3 import Web3
import json, time


# Load CSV file from your Homework 1
import pandas as pd


# Load IoT sensor data from CSV file (Generated in Homework 1)
df = pd.read_csv('../Week 5 Homework/iot_data.csv')

# Display the first few rows of the DataFrame
print(df.head())

# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

# Check if connected to Ganache
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
    exit()

# Replace with actual contract address form Remix 
contract_address = "0x7772e6a1cbfFf847250B44aaCb2290Ba9b6F1347"

# Paste the ABI from Remix 
# abi = [...] # Replace with the actual ABI of your contract

# If you have the ABI in a file, you can load it like this:
with open('copy-of-abi.json', 'r') as abi_file:
    abi = json.load(abi_file)

# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)

# Set the default sender address (the first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")


# Send the IoT data to the blockchain. Each row from the CSV file will be stored as a transaction on the blockchain.
def send_iot_data(package_id, gps_coords, temperature, status):
    
    txn = contract.functions.storeData(
        package_id,
        gps_coords,
        temperature,
        status
    ).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
    
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Data Stored {package_id} GPS: {gps_coords:>23} Temp: {temperature}  Status: {status:<10} at block {
        receipt.blockNumber:>3} Txn hash {receipt.transactionHash.hex()}")


# Iterate through the DataFrame and send each row to the blockchain
for index, row in df.iterrows():

    package_id  = str(row['package_id'  ])
    gps_coords  = str(row['gps_coords'  ])
    temperature = str(row['temperature' ])
    status      = str(row['status'      ])    

    send_iot_data(package_id, gps_coords, temperature, status)    
    time.sleep(1)  # sleep to avoid hitting the gas limit too quickly

# now that the data is on the blockchain, we can retrieve it to verify storage
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")

# retrieve and print a specific record (e.g., the first one)
record = contract.functions.getRecord(0).call()
print(f"First Stored Record : {record}")
# Out:
#                timestamp package_id               gps_coords temperature  \
# 0  2025-06-02T21:36:32I0     PKG001   (7.839114, 125.820784)        29 C
# 1  2025-06-02T21:36:32I1     PKG002  (16.754497, 116.599905)        24 C
# 2  2025-06-02T21:36:32I2     PKG003  (16.521005, 119.641554)        29 C
# 3  2025-06-02T21:36:32I3     PKG004  (10.941567, 118.303819)        29 C
# 4  2025-06-02T21:36:32I4     PKG005   (9.844815, 118.509812)        29 C
#
#        status
# 0   Delivered
# 1   Delivered
# 2     Delayed
# 3   Delivered
# 4  In Transit
# ✅ Connected to Ganache successfully!
# ✅ Connected to Smart Contract at 0x7772e6a1cbfFf847250B44aaCb2290Ba9b6F1347
# ✅ Data Stored PKG001 GPS:  (7.839114, 125.820784) Temp: 29 C  Status: Delivered  at block   2 Txn hash 19fbb7c4745279ecc3046057e692b3d007e9664fc8654283b7138bed5bc2a0a8
# ✅ Data Stored PKG002 GPS: (16.754497, 116.599905) Temp: 24 C  Status: Delivered  at block   3 Txn hash 0e714d61602737dd2a8134f37c294497dfb486bb63803169cd943200aa4cc6d0
# ✅ Data Stored PKG003 GPS: (16.521005, 119.641554) Temp: 29 C  Status: Delayed    at block   4 Txn hash 9d115b2a3da3f31e4e26efa4726613d831236b8c75a7748cb48169a9d39517a5
# ✅ Data Stored PKG004 GPS: (10.941567, 118.303819) Temp: 29 C  Status: Delivered  at block   5 Txn hash 9e6292706da6272398559d9e473d2b9645010f8b41378d1849b4cc8e1864bc8b
# ✅ Data Stored PKG005 GPS:  (9.844815, 118.509812) Temp: 29 C  Status: In Transit at block   6 Txn hash 07520edd462233e68f9ea249cf2ce86e703062f00097ac9fc4586702e037f9ab
# ✅ Data Stored PKG006 GPS:   (8.86805, 120.813762) Temp: 30 C  Status: Delivered  at block   7 Txn hash 2ddc1987429b7480bedcb747c8ffaaf711d595642ed7b951a045bc0d1c5cd748
# ✅ Data Stored PKG007 GPS: (12.741756, 118.439917) Temp: 27 C  Status: In Transit at block   8 Txn hash 0c2d9c6f2c77856d71c0d8ad8fb99ff390b13a5064138d980a2603cd289beced
# ✅ Data Stored PKG008 GPS: (15.501252, 122.082088) Temp: 29 C  Status: Delivered  at block   9 Txn hash 7be0205e16ee3a47dd395f09a2f8d63019dd82e5de171d593a6f489d26bae318
# ✅ Data Stored PKG009 GPS:  (8.443512, 118.729713) Temp: 27 C  Status: In Transit at block  10 Txn hash 2e38a92505b350e4df4c356a674baee49621de72fc8c2cf0454afe67dbe78171
# ✅ Data Stored PKG010 GPS:  (7.319699, 126.018423) Temp: 24 C  Status: Delayed    at block  11 Txn hash c74444d0050d3483fa180b2bed28def72801cb28b4f91ec4a2a89c32ca533f53
# ✅ Data Stored PKG011 GPS: (17.975589, 121.024438) Temp: 30 C  Status: Delivered  at block  12 Txn hash 61150a7707f9590d6682fa131844f70a5a3ba20916f51dbe4e127f5f289c2240
# ✅ Data Stored PKG012 GPS: (20.895582, 116.357231) Temp: 24 C  Status: Delivered  at block  13 Txn hash d237d763466fe08b0f83e21d3f3b3adb3ba03f2d2af75cdd8c05ca8e31125088
# ✅ Data Stored PKG013 GPS:  (13.937566, 122.10715) Temp: 27 C  Status: Delayed    at block  14 Txn hash d12849d3369297e6deaf06ac2f2ad7d4b5f445001689e09cef3083ef9e9fd091
# ✅ Data Stored PKG014 GPS: (16.165907, 121.608117) Temp: 26 C  Status: Delayed    at block  15 Txn hash b331928793930c2afeced41b365841493cfb323e4bca560a0050a0a6f58e4b4d
# ✅ Data Stored PKG015 GPS: (16.311307, 118.017979) Temp: 27 C  Status: Delivered  at block  16 Txn hash f65138397baf83aad3b498b5547bb2c72ce66d1c5ae4e753d73f1706888608b4
# ✅ Data Stored PKG016 GPS:  (5.390759, 125.643993) Temp: 24 C  Status: Delayed    at block  17 Txn hash e71ca06174478311275dc0f852b700c1598f7dadb8d311367cfa9bbac5d9ce28
# ✅ Data Stored PKG017 GPS: (12.625246, 125.616081) Temp: 25 C  Status: Delayed    at block  18 Txn hash 0ca6d9381ca76fa22ea04626d18d075e3cafad20e4d7baeaabef86ecb2c61023
# ✅ Data Stored PKG018 GPS: (14.156132, 124.678982) Temp: 26 C  Status: In Transit at block  19 Txn hash aaf81637b4c9ff86b84b35f2ba4f409dde5ca54b1f57b4cbe8c4745505c6f2f1
# ✅ Data Stored PKG019 GPS: (19.627461, 121.054452) Temp: 29 C  Status: Delivered  at block  20 Txn hash 99c9e5df973f00e82469dee6151f53c97d970608f6ae7ec92ebe7bbaabd6a02f
# ✅ Data Stored PKG020 GPS:   (15.419375, 119.4685) Temp: 24 C  Status: Delayed    at block  21 Txn hash d3dffb8fba4c85412705a200c08ec807e1cbe2c3d144aa50727eb4dff07f9234
# ✅ Data Stored PKG021 GPS: (11.712474, 119.182333) Temp: 27 C  Status: In Transit at block  22 Txn hash f29b7b99a84e6c306f7d1bf9658c109fe7e57324c9d80bc072def02872ba43e0
# ✅ Data Stored PKG022 GPS:  (8.105608, 118.457009) Temp: 30 C  Status: In Transit at block  23 Txn hash 6cf581e288711aa71e94f71c337edbc8799340fac5e0bb70486aa3a7ea8323d5
# ✅ Data Stored PKG023 GPS:  (6.418801, 119.158313) Temp: 27 C  Status: Delivered  at block  24 Txn hash 155991a132cdb63e405fbe9c6a5d1d6b469a3d635f90fb2e5ee35bd0278e4ef3
# ✅ Data Stored PKG024 GPS: (11.360729, 124.448003) Temp: 30 C  Status: In Transit at block  25 Txn hash b6f21d078e5ad495b27268beb0d3b79da0b53b9e0ac36aaca88ac085b0ac2f4d
# ✅ Data Stored PKG025 GPS:  (7.264897, 117.127706) Temp: 24 C  Status: Delivered  at block  26 Txn hash afab2bdc2d5c392e831d8f2f2387cf520bae83bc3a19c17c15e162b3c88d4e21
# ✅ Data Stored PKG026 GPS:  (8.098239, 121.392044) Temp: 27 C  Status: In Transit at block  27 Txn hash 1a9925096d6b3dac889aa817eaca53228824eb4fd0f6684d467b42435cd6d699
# ✅ Data Stored PKG027 GPS:  (8.625353, 123.941422) Temp: 25 C  Status: Delivered  at block  28 Txn hash e3bb7f51008659ac713289c098f6a331cf4e0250ea28cb598a36ecffc436f279
# ✅ Data Stored PKG028 GPS: (15.677987, 123.517964) Temp: 26 C  Status: In Transit at block  29 Txn hash 665a964bf9ae969c24493e1885c44bee359082431b0296c99c4816d896827264
# ✅ Data Stored PKG029 GPS: (17.602117, 123.518825) Temp: 26 C  Status: Delivered  at block  30 Txn hash dc0fd4249a5ce0f82c76cfb208f92d6b39acee671007e1df603a48f67c47a2f7
# ✅ Data Stored PKG030 GPS: (12.054201, 116.765579) Temp: 26 C  Status: Delayed    at block  31 Txn hash 63254d14087eec6f13cee7306c8ddbb8ce87a90b6b19f78d4b3b434333d44377
# ✅ Data Stored PKG031 GPS: (10.820827, 125.110851) Temp: 27 C  Status: Delayed    at block  32 Txn hash 31784b1c077a8e25801f4f6ec6452cff3121e0d760a66ff0bfe9ec7d31969190
# ✅ Data Stored PKG032 GPS:   (6.981207, 123.79629) Temp: 30 C  Status: In Transit at block  33 Txn hash dd62bc91fa185361cba2b9f03360389c1b1e5a102f4ceb432d19a750185da078
# ✅ Data Stored PKG033 GPS: (20.348736, 123.021186) Temp: 28 C  Status: Delayed    at block  34 Txn hash 73f10d0c8af1778e7ee10bdaede72026afd1badf398bcdbf619327187b6ca23d
# ✅ Data Stored PKG034 GPS:  (7.625714, 123.111139) Temp: 28 C  Status: In Transit at block  35 Txn hash f00b8d05b09d22b79f65a987e5bfebad276dcab87e5aec7ccdad5a56ecbcd86c
# ✅ Data Stored PKG035 GPS:  (9.426897, 125.750272) Temp: 24 C  Status: In Transit at block  36 Txn hash 82661a6c1ab993783ee6dd127de8dc2e3637515c1612e269ec8dc513ab05d294
# ✅ Data Stored PKG036 GPS:  (9.703381, 117.062399) Temp: 26 C  Status: Delayed    at block  37 Txn hash 384acebb3a5b20a0bd6551b5e36c689cbb9df70af43c705aaaf27d9a24fdbfa3
# ✅ Data Stored PKG037 GPS:  (19.694293, 125.22267) Temp: 26 C  Status: In Transit at block  38 Txn hash 3ffb270f25acf4661f7d7d134b8ba856b6a4cb6a2432503837d377d22beb3e08
# ✅ Data Stored PKG038 GPS: (15.375615, 123.952056) Temp: 27 C  Status: In Transit at block  39 Txn hash 4067fc682318817b8cf0ccf90c3d34fdfe0258fd8bad796205f2069688d6b693
# ✅ Data Stored PKG039 GPS: (18.475301, 121.448325) Temp: 28 C  Status: In Transit at block  40 Txn hash 60530f938f0f61aa8f95b93191e499b2b4a6c3f3a8cad3e6a876fa820ccff924
# ✅ Data Stored PKG040 GPS:  (16.58086, 123.536357) Temp: 28 C  Status: Delayed    at block  41 Txn hash 609dcbed93bfbefaa2f34a369c4f6892b169195c550ed9d38328cda7ece331c0
# ✅ Data Stored PKG041 GPS: (13.563926, 126.967492) Temp: 29 C  Status: Delayed    at block  42 Txn hash 5d805d12283c1f18ee42753546ff889705a4d16908457e3bcc31ea0bd59d6e6f
# ✅ Data Stored PKG042 GPS:  (19.480452, 116.36425) Temp: 27 C  Status: In Transit at block  43 Txn hash 1a96cda134fba7fb39e91437594bc35c1c91cb73a33a76c27b320335668cbf28
# ✅ Data Stored PKG043 GPS: (11.194763, 124.513853) Temp: 27 C  Status: Delayed    at block  44 Txn hash 4a5cd830446ae4786eb68034306d1b808a400bbdeb1c4e2ef33c8c7fcbcd3c37
# ✅ Data Stored PKG044 GPS:  (8.178935, 118.121624) Temp: 24 C  Status: Delivered  at block  45 Txn hash 155422c5df7f8658cba1c822b55a357231c204e1066aff21c6cebee09aaa30c2
# ✅ Data Stored PKG045 GPS:  (11.680432, 124.44445) Temp: 24 C  Status: In Transit at block  46 Txn hash 188d4557a185d50d95799b3d19f75463de11f275e46d1b9ce3a224c0a71201a1
# ✅ Data Stored PKG046 GPS: (15.771875, 122.903814) Temp: 28 C  Status: Delayed    at block  47 Txn hash a6acfec5a2047c0025e65e297cfe9ad5559cbdf4fde46517ea03a88c7f7bcf65
# ✅ Data Stored PKG047 GPS: (12.040084, 116.369242) Temp: 27 C  Status: In Transit at block  48 Txn hash b7984f0f90d6facc0ab90ba9df4afde6224f360d48cee0c3b193e0f1ff968daf
# ✅ Data Stored PKG048 GPS: (14.732945, 121.222389) Temp: 29 C  Status: In Transit at block  49 Txn hash b3658ad67fcc73b9470e4e4065159bdb63f06cfd0298d607c06fd125b5ce1fbf
# ✅ Data Stored PKG049 GPS: (11.035818, 118.615475) Temp: 28 C  Status: Delivered  at block  50 Txn hash 99e5c413333e7495f6e8ef9c39bd3ac07ed49bac1759d7874e4b50dd4a795f9a
# ✅ Data Stored PKG050 GPS: (10.548708, 126.350368) Temp: 26 C  Status: In Transit at block  51 Txn hash 761e2fc8f3779e62dfe8f513a0c0cacb6cc6492770b1b5a12aa28ccec0c508ce
# ✅ Data Stored PKG051 GPS: (13.914717, 116.106482) Temp: 30 C  Status: Delayed    at block  52 Txn hash bb390b93a50872c5005b378a9715a641b46edef439b0950ed54ba9a046cea8d3
# ✅ Data Stored PKG052 GPS: (14.597959, 125.412033) Temp: 27 C  Status: In Transit at block  53 Txn hash f19ed6ae9f8f4cee022462841f3413bbb02617c2261c46a9428c969ce312c855
# ✅ Data Stored PKG053 GPS: (20.834108, 120.921661) Temp: 26 C  Status: Delivered  at block  54 Txn hash 265393b8f5a1b91f10b2ca3f667cf172f4bea513e55dddd2b99e7c579bc94cd1
# ✅ Data Stored PKG054 GPS:   (9.231447, 122.26437) Temp: 30 C  Status: In Transit at block  55 Txn hash b967eff11c4ccd8d8a1eade0496ccfd3f0dd8bdae2358ce8d1a822a0d6866a22
# ✅ Data Stored PKG055 GPS:  (4.505109, 116.363897) Temp: 24 C  Status: In Transit at block  56 Txn hash 87003c84cc59a5b94dc4cc401451a90e31447a1382f6f10bad916d1ba8b2b1eb
# ✅ Data Stored PKG056 GPS: (14.097964, 116.040866) Temp: 27 C  Status: In Transit at block  57 Txn hash 1e05b7b7249a80c261574ade01a07920942e7966b0f74b48cb0f8231bd5ea5fb
# ✅ Data Stored PKG057 GPS:  (17.949557, 119.85132) Temp: 24 C  Status: Delayed    at block  58 Txn hash f5b8fd1779ffd806198a5c56fbed7a05f7e31ecdcc8e07970383f284297acd70
# ✅ Data Stored PKG058 GPS:  (5.844681, 124.776239) Temp: 27 C  Status: Delivered  at block  59 Txn hash cfd8caf0e89d69f2e033118521f69f28f84b1ee318f3c6188cb495ec7824d5c3
# ✅ Data Stored PKG059 GPS:  (7.631688, 116.979815) Temp: 25 C  Status: Delayed    at block  60 Txn hash 775c5eed9f04f828f58b9486c80031bca94fccdf3e93163a26eea4fdadf423d6
# ✅ Data Stored PKG060 GPS:  (8.679544, 120.659995) Temp: 24 C  Status: Delayed    at block  61 Txn hash 55d14af95ff38b8034a5926b7f6323f0b627c6bd4b84c10a93f6d824ade27cd5
# ✅ Data Stored PKG061 GPS: (19.975022, 124.454962) Temp: 24 C  Status: Delivered  at block  62 Txn hash a78a3f13e825a0b94759bc0438a0131da88efbfa80b4085315d7a6c7a3baaa7e
# ✅ Data Stored PKG062 GPS: (11.411139, 116.574568) Temp: 28 C  Status: Delivered  at block  63 Txn hash ff872d524be541c16c3835122b327c7b7a6f0683ef0866917a5d5f1b4e7abec3
# ✅ Data Stored PKG063 GPS:   (4.537106, 120.18287) Temp: 29 C  Status: Delivered  at block  64 Txn hash 33d085ed1eb0b40c946c46251c143cfb17c419db068ab8e75d1a18746ce8fbc3
# ✅ Data Stored PKG064 GPS:   (7.939288, 124.22867) Temp: 25 C  Status: In Transit at block  65 Txn hash 8f8b98e511c6f9ac5a08f195e03f1f5ebeec036466acacd3341274fbd3f18a8f
# ✅ Data Stored PKG065 GPS:  (7.082617, 116.000626) Temp: 27 C  Status: Delayed    at block  66 Txn hash 528e4840240087ca52625740b467701a521149d966ca12ebe9c1354a5c197564
# ✅ Data Stored PKG066 GPS: (10.838625, 117.070254) Temp: 29 C  Status: Delayed    at block  67 Txn hash 61d1894900c9869cc156f6c7bc2d61eb8fff4bbd92d32481f0d98e525737e51c
# ✅ Data Stored PKG067 GPS:    (8.899587, 116.0402) Temp: 27 C  Status: Delivered  at block  68 Txn hash dba569176e735b1a6f3c02d4c9687739dbd037b58f9decb718f9c431794408ae
# ✅ Data Stored PKG068 GPS:  (7.145796, 118.263733) Temp: 26 C  Status: Delayed    at block  69 Txn hash 62f3ffcee020799d083fae0fff2f7db893b091c08accf7db1609bc97c248417f
# ✅ Data Stored PKG069 GPS: (20.308394, 123.106085) Temp: 28 C  Status: Delayed    at block  70 Txn hash c79b88bf7189d58043c0ee9807f83bffefb3346eb5dcab971ea2e3ebd450c0a8
# ✅ Data Stored PKG070 GPS:  (5.709838, 125.649678) Temp: 28 C  Status: In Transit at block  71 Txn hash 9dfa0434f20746863ef6ef65ac84cd8dc7aabbd2cc8e3b803d5a0a79b0d6bc9c
# ✅ Data Stored PKG071 GPS:  (6.839736, 123.498628) Temp: 29 C  Status: Delayed    at block  72 Txn hash 0c5fbfaaea91a61cd7212813ddb4a5320138cc9fa59608996721d38580054d5a
# ✅ Data Stored PKG072 GPS: (13.995788, 126.724895) Temp: 26 C  Status: In Transit at block  73 Txn hash e0007bed6dfcaddca5d60675c11b8c16f2da4cd6ca7fa1b2026a7b534dbd5bba
# ✅ Data Stored PKG073 GPS:  (9.465027, 116.899757) Temp: 24 C  Status: Delivered  at block  74 Txn hash 3ce8301554264388a3de97f6dc95111c674da738fc4cb344b2e0a76d31210eaf
# ✅ Data Stored PKG074 GPS:  (5.740364, 123.984693) Temp: 24 C  Status: In Transit at block  75 Txn hash f1c9523196395e228f6c3e8ea599a4dc47737f364fdab4f2b0d241154c21ac8b
# ✅ Data Stored PKG075 GPS:  (7.041248, 122.272286) Temp: 27 C  Status: Delayed    at block  76 Txn hash 56e019c52d6f715f7f4fd3c7d56325ca03bc76099b84a4a1d982b9ead83c1bb3
# ✅ Data Stored PKG076 GPS: (18.078201, 118.168643) Temp: 27 C  Status: In Transit at block  77 Txn hash 4e1da5f84c41a12fef802797871a55dbdf1a9d472244212b569a626b4499f588
# ✅ Data Stored PKG077 GPS: (20.868882, 119.887165) Temp: 24 C  Status: Delayed    at block  78 Txn hash 7c2ceea92f5c57f7f7e3146721ab225a60f9b332c4fdb86450fbe79dc7515c32
# ✅ Data Stored PKG078 GPS: (11.530742, 117.739627) Temp: 27 C  Status: Delayed    at block  79 Txn hash 2a31ee52f3db8769b95ef0ef62ed12aaa0e3675271f6a43e3a552a38a2902e72
# ✅ Data Stored PKG079 GPS: (14.155735, 122.167592) Temp: 24 C  Status: Delivered  at block  80 Txn hash 6a4093f33f934f3e2b12b3720d4973f7064ef0cd37513c2ac6d43e7a52e26350
# ✅ Data Stored PKG080 GPS:  (5.745231, 116.345228) Temp: 25 C  Status: In Transit at block  81 Txn hash ed7d35084438252c6926e6efbb0caa222eb23ed0677742dd1c6113a3e58bb82e
# ✅ Data Stored PKG081 GPS: (13.299741, 124.639463) Temp: 25 C  Status: Delayed    at block  82 Txn hash bd96d44938fad33a088a71c3771bbb772693c6fa9a2b7a888d074297135b2e1d
# ✅ Data Stored PKG082 GPS:  (17.439801, 125.83448) Temp: 29 C  Status: In Transit at block  83 Txn hash 75228314d9d8abc70ed883c70a9c163c5a9438e9c8b4188e4737b5a2f7f7413a
# ✅ Data Stored PKG083 GPS:  (5.517328, 118.667595) Temp: 25 C  Status: In Transit at block  84 Txn hash 21d7e77d032d6c80673111e7af3b58857f6f63901e2e4ee9640e1535de9ae4a0
# ✅ Data Stored PKG084 GPS: (19.391768, 118.548733) Temp: 28 C  Status: In Transit at block  85 Txn hash 7afb795652d1550eb4636ecf4f0fb77fd8cd660a60e329202335cdc7bc88b928
# ✅ Data Stored PKG085 GPS: (17.220957, 126.098216) Temp: 27 C  Status: Delayed    at block  86 Txn hash e71f88a6eaf0a207af9a21608e1e6218022637f3993b4ccf70dcfc940ac739a9
# ✅ Data Stored PKG086 GPS:  (7.731702, 117.299307) Temp: 25 C  Status: In Transit at block  87 Txn hash e99f2072dbace7240c525f53374fdc1db71e4ac9afa2709dc55f9a5094e127fd
# ✅ Data Stored PKG087 GPS:  (5.563162, 125.435676) Temp: 25 C  Status: In Transit at block  88 Txn hash cf292a4909cad73e98a00bf9b634319b079579b241ad472925d1078007854b8b
# ✅ Data Stored PKG088 GPS:  (7.023184, 121.483225) Temp: 25 C  Status: Delayed    at block  89 Txn hash eaa15ee3d0985cc72f6111400fab9afc76df668a8deaa0549b56a77b3fce15cf
# ✅ Data Stored PKG089 GPS: (14.735133, 116.891753) Temp: 28 C  Status: Delivered  at block  90 Txn hash 85a58fcfa0bdb1483151f6e1191b0c499789864337b6c12719c582ba80b51e2a
# ✅ Data Stored PKG090 GPS: (10.266517, 124.031933) Temp: 27 C  Status: Delivered  at block  91 Txn hash 9898f15cd30e570857581a859dacbdacfb1da07b337fb302c019e7de98606a14
# ✅ Data Stored PKG091 GPS:  (19.872964, 123.86125) Temp: 27 C  Status: In Transit at block  92 Txn hash 0269986c44c651ea2f493b9adc314a21623382d3aad05bcbf0197b215819beb1
# ✅ Data Stored PKG092 GPS: (14.481173, 117.737989) Temp: 28 C  Status: In Transit at block  93 Txn hash 1164c9b06133baacf1932b3876120c5d9812c9ca37dc2b39377340d5a4721711
# ✅ Data Stored PKG093 GPS: (16.730197, 118.481903) Temp: 24 C  Status: In Transit at block  94 Txn hash c77cbbc1db46de0f7848eba52d20146e344aa71336c129195af5309bd480952a
# ✅ Data Stored PKG094 GPS: (12.760738, 117.442269) Temp: 26 C  Status: In Transit at block  95 Txn hash aa81445571ea466cfb0ba3f20d22c9fb292a1494798e2c2612373534538d8cea
# ✅ Data Stored PKG095 GPS:   (6.622769, 125.03202) Temp: 25 C  Status: Delivered  at block  96 Txn hash b6989b1b05c61cdec1ea12c53d56bc3eafd1376b2fcff8da89f36c173fcb4a4e
# ✅ Data Stored PKG096 GPS: (12.998725, 125.744701) Temp: 28 C  Status: Delayed    at block  97 Txn hash 3869c516eb70ef023c9358993b5e7473736a2e1714701d67642265be58c7efda
# ✅ Data Stored PKG097 GPS:  (20.336235, 126.65279) Temp: 27 C  Status: Delayed    at block  98 Txn hash 14503086ab4fa3ad7b682ae6da556269bd4f3440220f6de4672ec21ebcbf108b
# ✅ Data Stored PKG098 GPS:  (8.659069, 126.519407) Temp: 26 C  Status: Delayed    at block  99 Txn hash bf6c38ce6fa0d5ad9742066e68ce9c0d84ddf44cd10380262c84e4034751ce80
# ✅ Data Stored PKG099 GPS:  (9.128521, 123.681135) Temp: 24 C  Status: Delayed    at block 100 Txn hash 7fc545e1dd608c27041248f12fbefc28265b541ba9b6b26eaf7dc05afc0a30ae
# ✅ Data Stored PKG100 GPS:  (8.911339, 126.627085) Temp: 27 C  Status: Delayed    at block 101 Txn hash f554c036abf4d478c23055c0177f02cabf3560233338f552761498e730a9b3f4
# Total IoT records stored: 100
# First Stored Record : [1749315403, 'PKG001', '(7.839114, 125.820784)', '29 C', 'Delivered']
